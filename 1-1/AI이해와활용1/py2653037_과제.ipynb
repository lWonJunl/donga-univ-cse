# %%
print("Hello World!!")
# Out:
# Hello World!!

# %%
# 주석문(설명문)
# 변수 / 자료형
# 기계어 : 010101010101
# 변수 : 데이터의 위치
# 자료형 : 정수, 실수, 문자, 문자열, Boolean(True/False)

# %%
a = 100     #주기억장치 a <= 변수 
b = 200
sum = a+b
print("합계 = ", sum)
# Out:
# 합계 =  300

# %%
# 변수이름 : 
# 1. 소문자로 시작 / 대소문자 구분 : num = 10, Num = 20
# 2. 문자와 숫자의 조합
# 3. 숫자로 시작하면 안됨
# 4. 변수명에 공백이 있으면 안된다.
# 5. 특수문자는 (_)만 가능하다.
